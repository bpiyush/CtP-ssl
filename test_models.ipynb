# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from torchsummary import summary

from pyvrl.models.backbones.r3d import R2Plus1D

# %% [markdown]
# ### Default backbone

# %%
backbone_args=dict(
    depth=18,
    num_stages=4,
    stem=dict(
        temporal_kernel_size=3,
        temporal_stride=1,
        in_channels=3,
        with_pool=False,
    ),
    down_sampling=[False, True, True, True],
    down_sampling_temporal=[False, True, True, True],
    channel_multiplier=1.0,
    bottleneck_multiplier=1.0,
    with_bn=True,
    zero_init_residual=False
)

# %%
backbone = R2Plus1D(**backbone_args)

# %%
x = torch.randn(1, 3, 16, 112, 112)

# %%
y = backbone(x)

# %%
y.shape
# Out:
# torch.Size([1, 512, 2, 7, 7])

# %%
summary(backbone, (3, 16, 112, 112))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1       [-1, 45, 16, 56, 56]           6,615
#        BatchNorm3d-2       [-1, 45, 16, 56, 56]              90
#               ReLU-3       [-1, 45, 16, 56, 56]               0
#             Conv3d-4       [-1, 64, 16, 56, 56]           8,640
#        BatchNorm3d-5       [-1, 64, 16, 56, 56]             128
#               ReLU-6       [-1, 64, 16, 56, 56]               0
#             Conv3d-7      [-1, 144, 16, 56, 56]          82,944
#        BatchNorm3d-8      [-1, 144, 16, 56, 56]             288
#               ReLU-9      [-1, 144, 16, 56, 56]               0
#            Conv3d-10       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-11       [-1, 64, 16, 56, 56]             128
#              ReLU-12       [-1, 64, 16, 56, 56]               0
#            Conv3d-13      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-14      [-1, 144, 16, 56, 56]             288
#              ReLU-15      [-1, 144, 16, 56, 56]               0
#            Conv3d-16       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-17       [-1, 64, 16, 56, 56]             128
#              ReLU-18       [-1, 64, 16, 56, 56]               0
#        BasicBlock-19       [-1, 64, 16, 56, 56]               0
#            Conv3d-20      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-21      [-1, 144, 16, 56, 56]             288
#              ReLU-22      [-1, 144, 16, 56, 56]               0
#            Conv3d-23       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-24       [-1, 64, 16, 56, 56]             128
#              ReLU-25       [-1, 64, 16, 56, 56]               0
#            Conv3d-26      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-27      [-1, 144, 16, 56, 56]             288
#              ReLU-28      [-1, 144, 16, 56, 56]               0
#            Conv3d-29       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-30       [-1, 64, 16, 56, 56]             128
#              ReLU-31       [-1, 64, 16, 56, 56]               0
#        BasicBlock-32       [-1, 64, 16, 56, 56]               0
#            Conv3d-33      [-1, 230, 16, 28, 28]         132,480
#       BatchNorm3d-34      [-1, 230, 16, 28, 28]             460
#              ReLU-35      [-1, 230, 16, 28, 28]               0
#            Conv3d-36       [-1, 128, 8, 28, 28]          88,320
#       BatchNorm3d-37       [-1, 128, 8, 28, 28]             256
#              ReLU-38       [-1, 128, 8, 28, 28]               0
#            Conv3d-39       [-1, 230, 8, 28, 28]         264,960
#       BatchNorm3d-40       [-1, 230, 8, 28, 28]             460
#              ReLU-41       [-1, 230, 8, 28, 28]               0
#            Conv3d-42       [-1, 128, 8, 28, 28]          88,320
#       BatchNorm3d-43       [-1, 128, 8, 28, 28]             256
#            Conv3d-44       [-1, 128, 8, 28, 28]           8,192
#       BatchNorm3d-45       [-1, 128, 8, 28, 28]             256
#              ReLU-46       [-1, 128, 8, 28, 28]               0
#        BasicBlock-47       [-1, 128, 8, 28, 28]               0
#            Conv3d-48       [-1, 288, 8, 28, 28]         331,776
#       BatchNorm3d-49       [-1, 288, 8, 28, 28]             576
#              ReLU-50       [-1, 288, 8, 28, 28]               0
#            Conv3d-51       [-1, 128, 8, 28, 28]         110,592
#       BatchNorm3d-52       [-1, 128, 8, 28, 28]             256
#              ReLU-53       [-1, 128, 8, 28, 28]               0
#            Conv3d-54       [-1, 288, 8, 28, 28]         331,776
#       BatchNorm3d-55       [-1, 288, 8, 28, 28]             576
#              ReLU-56       [-1, 288, 8, 28, 28]               0
#            Conv3d-57       [-1, 128, 8, 28, 28]         110,592
#       BatchNorm3d-58       [-1, 128, 8, 28, 28]             256
#              ReLU-59       [-1, 128, 8, 28, 28]               0
#        BasicBlock-60       [-1, 128, 8, 28, 28]               0
#            Conv3d-61       [-1, 460, 8, 14, 14]         529,920
#       BatchNorm3d-62       [-1, 460, 8, 14, 14]             920
#              ReLU-63       [-1, 460, 8, 14, 14]               0
#            Conv3d-64       [-1, 256, 4, 14, 14]         353,280
#       BatchNorm3d-65       [-1, 256, 4, 14, 14]             512
#              ReLU-66       [-1, 256, 4, 14, 14]               0
#            Conv3d-67       [-1, 460, 4, 14, 14]       1,059,840
#       BatchNorm3d-68       [-1, 460, 4, 14, 14]             920
#              ReLU-69       [-1, 460, 4, 14, 14]               0
#            Conv3d-70       [-1, 256, 4, 14, 14]         353,280
#       BatchNorm3d-71       [-1, 256, 4, 14, 14]             512
#            Conv3d-72       [-1, 256, 4, 14, 14]          32,768
#       BatchNorm3d-73       [-1, 256, 4, 14, 14]             512
#              ReLU-74       [-1, 256, 4, 14, 14]               0
#        BasicBlock-75       [-1, 256, 4, 14, 14]               0
#            Conv3d-76       [-1, 576, 4, 14, 14]       1,327,104
#       BatchNorm3d-77       [-1, 576, 4, 14, 14]           1,152
#              ReLU-78       [-1, 576, 4, 14, 14]               0
#            Conv3d-79       [-1, 256, 4, 14, 14]         442,368
#       BatchNorm3d-80       [-1, 256, 4, 14, 14]             512
#              ReLU-81       [-1, 256, 4, 14, 14]               0
#            Conv3d-82       [-1, 576, 4, 14, 14]       1,327,104
#       BatchNorm3d-83       [-1, 576, 4, 14, 14]           1,152
#              ReLU-84       [-1, 576, 4, 14, 14]               0
#            Conv3d-85       [-1, 256, 4, 14, 14]         442,368
#       BatchNorm3d-86       [-1, 256, 4, 14, 14]             512
#              ReLU-87       [-1, 256, 4, 14, 14]               0
#        BasicBlock-88       [-1, 256, 4, 14, 14]               0
#            Conv3d-89         [-1, 921, 4, 7, 7]       2,121,984
#       BatchNorm3d-90         [-1, 921, 4, 7, 7]           1,842
#              ReLU-91         [-1, 921, 4, 7, 7]               0
#            Conv3d-92         [-1, 512, 2, 7, 7]       1,414,656
#       BatchNorm3d-93         [-1, 512, 2, 7, 7]           1,024
#              ReLU-94         [-1, 512, 2, 7, 7]               0
#            Conv3d-95         [-1, 921, 2, 7, 7]       4,243,968
#       BatchNorm3d-96         [-1, 921, 2, 7, 7]           1,842
#              ReLU-97         [-1, 921, 2, 7, 7]               0
#            Conv3d-98         [-1, 512, 2, 7, 7]       1,414,656
#       BatchNorm3d-99         [-1, 512, 2, 7, 7]           1,024
#           Conv3d-100         [-1, 512, 2, 7, 7]         131,072
#      BatchNorm3d-101         [-1, 512, 2, 7, 7]           1,024
#             ReLU-102         [-1, 512, 2, 7, 7]               0
#       BasicBlock-103         [-1, 512, 2, 7, 7]               0
#           Conv3d-104        [-1, 1152, 2, 7, 7]       5,308,416
#      BatchNorm3d-105        [-1, 1152, 2, 7, 7]           2,304
#             ReLU-106        [-1, 1152, 2, 7, 7]               0
#           Conv3d-107         [-1, 512, 2, 7, 7]       1,769,472
#      BatchNorm3d-108         [-1, 512, 2, 7, 7]           1,024
#             ReLU-109         [-1, 512, 2, 7, 7]               0
#           Conv3d-110        [-1, 1152, 2, 7, 7]       5,308,416
#      BatchNorm3d-111        [-1, 1152, 2, 7, 7]           2,304
#             ReLU-112        [-1, 1152, 2, 7, 7]               0
#           Conv3d-113         [-1, 512, 2, 7, 7]       1,769,472
#      BatchNorm3d-114         [-1, 512, 2, 7, 7]           1,024
#             ReLU-115         [-1, 512, 2, 7, 7]               0
#       BasicBlock-116         [-1, 512, 2, 7, 7]               0
# ================================================================
# Total params: 31,300,125
# Trainable params: 31,300,125
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 2.30
# Forward/backward pass size (MB): 1496.85
# Params size (MB): 119.40
# Estimated Total Size (MB): 1618.54
# ----------------------------------------------------------------

# %% [markdown]
# ### Customized backbone

# %%
backbone_args=dict(
    depth=18,
    num_stages=4,
    stem=dict(
        temporal_kernel_size=3,
        temporal_stride=1,
        in_channels=3,
        with_pool=False,
    ),
    down_sampling=[False, True, True, True],
    down_sampling_temporal=[False, True, True, True],
    channel_multiplier=1.0,
    bottleneck_multiplier=1.0,
    with_bn=True,
    zero_init_residual=False
)
# Out:
# [autoreload of pyvrl.models.backbones.r3d failed: Traceback (most recent call last):
#   File "/home/fmthoker/anaconda3/envs/ctp4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/fmthoker/anaconda3/envs/ctp4/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/fmthoker/anaconda3/envs/ctp4/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/fmthoker/anaconda3/envs/ctp4/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/gpfs/scratch1/shared/fmthoker/pbagad/CtP-ssl/pyvrl/models/backbones/r3d.py", line 450, in <module>
#     class R2Plus1D(BaseResNet3D):
#   File "/home/fmthoker/anaconda3/envs/ctp4/lib/python3.7/site-packages/mmcv/utils/registry.py", line 313, in _register
#     module_class=cls, module_name=name, force=force)
#   File "/home/fmthoker/anaconda3/envs/ctp4/lib/python3.7/site-packages/mmcv/utils/registry.py", line 246, in _register_module
#     raise KeyError(f'{name} is already registered '
# KeyError: 'R2Plus1D is already registered in backbone'
# ]

# %%
backbone = R2Plus1D(**backbone_args)

# %%
x = torch.randn(1, 3, 16, 112, 112)

# %%
y = backbone(x)

# %%
backbone
# Out:
# R2Plus1D(
#   (stem): Sequential(
#     (conv_s): Conv3d(3, 45, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#     (bn_s): BatchNorm3d(45, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_s): ReLU(inplace=True)
#     (conv_t): Conv3d(45, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#     (bn_t): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu_t): ReLU(inplace=True)
#   )
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(64, 230, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(230, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(230, 128, kernel_size=(3, 1, 1), stride=(2, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (conv): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(2, 1, 1), bias=False)
#       )
#       (downsample_bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(128, 460, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(460, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(460, 256, kernel_size=(3, 1, 1), stride=(2, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (conv): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(2, 1, 1), bias=False)
#       )
#       (downsample_bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(576, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(256, 921, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(921, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(921, 512, kernel_size=(3, 1, 1), stride=(2, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(1152, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (conv): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 1, 1), bias=False)
#       )
#       (downsample_bn): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (conv_s): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(1152, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn1): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Sequential(
#         (conv_s): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (bn_s): BatchNorm3d(1152, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu_s): ReLU(inplace=True)
#         (conv_t): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       )
#       (bn2): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
# )

# %%
y.shape
# Out:
# torch.Size([1, 512, 2, 56, 56])

# %%
summary(backbone, (3, 16, 112, 112))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1       [-1, 45, 16, 56, 56]           6,615
#        BatchNorm3d-2       [-1, 45, 16, 56, 56]              90
#               ReLU-3       [-1, 45, 16, 56, 56]               0
#             Conv3d-4       [-1, 64, 16, 56, 56]           8,640
#        BatchNorm3d-5       [-1, 64, 16, 56, 56]             128
#               ReLU-6       [-1, 64, 16, 56, 56]               0
#             Conv3d-7      [-1, 144, 16, 56, 56]          82,944
#        BatchNorm3d-8      [-1, 144, 16, 56, 56]             288
#               ReLU-9      [-1, 144, 16, 56, 56]               0
#            Conv3d-10       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-11       [-1, 64, 16, 56, 56]             128
#              ReLU-12       [-1, 64, 16, 56, 56]               0
#            Conv3d-13      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-14      [-1, 144, 16, 56, 56]             288
#              ReLU-15      [-1, 144, 16, 56, 56]               0
#            Conv3d-16       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-17       [-1, 64, 16, 56, 56]             128
#              ReLU-18       [-1, 64, 16, 56, 56]               0
#        BasicBlock-19       [-1, 64, 16, 56, 56]               0
#            Conv3d-20      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-21      [-1, 144, 16, 56, 56]             288
#              ReLU-22      [-1, 144, 16, 56, 56]               0
#            Conv3d-23       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-24       [-1, 64, 16, 56, 56]             128
#              ReLU-25       [-1, 64, 16, 56, 56]               0
#            Conv3d-26      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-27      [-1, 144, 16, 56, 56]             288
#              ReLU-28      [-1, 144, 16, 56, 56]               0
#            Conv3d-29       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-30       [-1, 64, 16, 56, 56]             128
#              ReLU-31       [-1, 64, 16, 56, 56]               0
#        BasicBlock-32       [-1, 64, 16, 56, 56]               0
#            Conv3d-33      [-1, 230, 16, 56, 56]         132,480
#       BatchNorm3d-34      [-1, 230, 16, 56, 56]             460
#              ReLU-35      [-1, 230, 16, 56, 56]               0
#            Conv3d-36       [-1, 128, 8, 56, 56]          88,320
#       BatchNorm3d-37       [-1, 128, 8, 56, 56]             256
#              ReLU-38       [-1, 128, 8, 56, 56]               0
#            Conv3d-39       [-1, 288, 8, 56, 56]         331,776
#       BatchNorm3d-40       [-1, 288, 8, 56, 56]             576
#              ReLU-41       [-1, 288, 8, 56, 56]               0
#            Conv3d-42       [-1, 128, 8, 56, 56]         110,592
#       BatchNorm3d-43       [-1, 128, 8, 56, 56]             256
#            Conv3d-44       [-1, 128, 8, 56, 56]           8,192
#       BatchNorm3d-45       [-1, 128, 8, 56, 56]             256
#              ReLU-46       [-1, 128, 8, 56, 56]               0
#        BasicBlock-47       [-1, 128, 8, 56, 56]               0
#            Conv3d-48       [-1, 288, 8, 56, 56]         331,776
#       BatchNorm3d-49       [-1, 288, 8, 56, 56]             576
#              ReLU-50       [-1, 288, 8, 56, 56]               0
#            Conv3d-51       [-1, 128, 8, 56, 56]         110,592
#       BatchNorm3d-52       [-1, 128, 8, 56, 56]             256
#              ReLU-53       [-1, 128, 8, 56, 56]               0
#            Conv3d-54       [-1, 288, 8, 56, 56]         331,776
#       BatchNorm3d-55       [-1, 288, 8, 56, 56]             576
#              ReLU-56       [-1, 288, 8, 56, 56]               0
#            Conv3d-57       [-1, 128, 8, 56, 56]         110,592
#       BatchNorm3d-58       [-1, 128, 8, 56, 56]             256
#              ReLU-59       [-1, 128, 8, 56, 56]               0
#        BasicBlock-60       [-1, 128, 8, 56, 56]               0
#            Conv3d-61       [-1, 460, 8, 56, 56]         529,920
#       BatchNorm3d-62       [-1, 460, 8, 56, 56]             920
#              ReLU-63       [-1, 460, 8, 56, 56]               0
#            Conv3d-64       [-1, 256, 4, 56, 56]         353,280
#       BatchNorm3d-65       [-1, 256, 4, 56, 56]             512
#              ReLU-66       [-1, 256, 4, 56, 56]               0
#            Conv3d-67       [-1, 576, 4, 56, 56]       1,327,104
#       BatchNorm3d-68       [-1, 576, 4, 56, 56]           1,152
#              ReLU-69       [-1, 576, 4, 56, 56]               0
#            Conv3d-70       [-1, 256, 4, 56, 56]         442,368
#       BatchNorm3d-71       [-1, 256, 4, 56, 56]             512
#            Conv3d-72       [-1, 256, 4, 56, 56]          32,768
#       BatchNorm3d-73       [-1, 256, 4, 56, 56]             512
#              ReLU-74       [-1, 256, 4, 56, 56]               0
#        BasicBlock-75       [-1, 256, 4, 56, 56]               0
#            Conv3d-76       [-1, 576, 4, 56, 56]       1,327,104
#       BatchNorm3d-77       [-1, 576, 4, 56, 56]           1,152
#              ReLU-78       [-1, 576, 4, 56, 56]               0
#            Conv3d-79       [-1, 256, 4, 56, 56]         442,368
#       BatchNorm3d-80       [-1, 256, 4, 56, 56]             512
#              ReLU-81       [-1, 256, 4, 56, 56]               0
#            Conv3d-82       [-1, 576, 4, 56, 56]       1,327,104
#       BatchNorm3d-83       [-1, 576, 4, 56, 56]           1,152
#              ReLU-84       [-1, 576, 4, 56, 56]               0
#            Conv3d-85       [-1, 256, 4, 56, 56]         442,368
#       BatchNorm3d-86       [-1, 256, 4, 56, 56]             512
#              ReLU-87       [-1, 256, 4, 56, 56]               0
#        BasicBlock-88       [-1, 256, 4, 56, 56]               0
#            Conv3d-89       [-1, 921, 4, 56, 56]       2,121,984
#       BatchNorm3d-90       [-1, 921, 4, 56, 56]           1,842
#              ReLU-91       [-1, 921, 4, 56, 56]               0
#            Conv3d-92       [-1, 512, 2, 56, 56]       1,414,656
#       BatchNorm3d-93       [-1, 512, 2, 56, 56]           1,024
#              ReLU-94       [-1, 512, 2, 56, 56]               0
#            Conv3d-95      [-1, 1152, 2, 56, 56]       5,308,416
#       BatchNorm3d-96      [-1, 1152, 2, 56, 56]           2,304
#              ReLU-97      [-1, 1152, 2, 56, 56]               0
#            Conv3d-98       [-1, 512, 2, 56, 56]       1,769,472
#       BatchNorm3d-99       [-1, 512, 2, 56, 56]           1,024
#           Conv3d-100       [-1, 512, 2, 56, 56]         131,072
#      BatchNorm3d-101       [-1, 512, 2, 56, 56]           1,024
#             ReLU-102       [-1, 512, 2, 56, 56]               0
#       BasicBlock-103       [-1, 512, 2, 56, 56]               0
#           Conv3d-104      [-1, 1152, 2, 56, 56]       5,308,416
#      BatchNorm3d-105      [-1, 1152, 2, 56, 56]           2,304
#             ReLU-106      [-1, 1152, 2, 56, 56]               0
#           Conv3d-107       [-1, 512, 2, 56, 56]       1,769,472
#      BatchNorm3d-108       [-1, 512, 2, 56, 56]           1,024
#             ReLU-109       [-1, 512, 2, 56, 56]               0
#           Conv3d-110      [-1, 1152, 2, 56, 56]       5,308,416
#      BatchNorm3d-111      [-1, 1152, 2, 56, 56]           2,304
#             ReLU-112      [-1, 1152, 2, 56, 56]               0
#           Conv3d-113       [-1, 512, 2, 56, 56]       1,769,472
#      BatchNorm3d-114       [-1, 512, 2, 56, 56]           1,024
#             ReLU-115       [-1, 512, 2, 56, 56]               0
#       BasicBlock-116       [-1, 512, 2, 56, 56]               0
# ================================================================
# Total params: 33,165,639
# Trainable params: 33,165,639
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 2.30
# Forward/backward pass size (MB): 4586.76
# Params size (MB): 126.52
# Estimated Total Size (MB): 4715.58
# ----------------------------------------------------------------

# %% [markdown]
# ### Pytorch R2Plus1D

# %%
from pyvrl.models.backbones.r3d_pytorch import r2plus1d_18

# %%
backbone = r2plus1d_18()
# Out:
# 144
# 144
# 230
# 288
# 460
# 576
# 921
# 1152

# %%
y = backbone(x)

# %%
y.shape
# Out:
# torch.Size([1, 512, 2, 7, 7])

# %%
summary(backbone, (3, 16, 112, 112))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1       [-1, 45, 16, 56, 56]           6,615
#        BatchNorm3d-2       [-1, 45, 16, 56, 56]              90
#               ReLU-3       [-1, 45, 16, 56, 56]               0
#             Conv3d-4       [-1, 64, 16, 56, 56]           8,640
#        BatchNorm3d-5       [-1, 64, 16, 56, 56]             128
#               ReLU-6       [-1, 64, 16, 56, 56]               0
#             Conv3d-7      [-1, 144, 16, 56, 56]          82,944
#        BatchNorm3d-8      [-1, 144, 16, 56, 56]             288
#               ReLU-9      [-1, 144, 16, 56, 56]               0
#            Conv3d-10       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-11       [-1, 64, 16, 56, 56]             128
#              ReLU-12       [-1, 64, 16, 56, 56]               0
#            Conv3d-13      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-14      [-1, 144, 16, 56, 56]             288
#              ReLU-15      [-1, 144, 16, 56, 56]               0
#            Conv3d-16       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-17       [-1, 64, 16, 56, 56]             128
#              ReLU-18       [-1, 64, 16, 56, 56]               0
#        BasicBlock-19       [-1, 64, 16, 56, 56]               0
#            Conv3d-20      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-21      [-1, 144, 16, 56, 56]             288
#              ReLU-22      [-1, 144, 16, 56, 56]               0
#            Conv3d-23       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-24       [-1, 64, 16, 56, 56]             128
#              ReLU-25       [-1, 64, 16, 56, 56]               0
#            Conv3d-26      [-1, 144, 16, 56, 56]          82,944
#       BatchNorm3d-27      [-1, 144, 16, 56, 56]             288
#              ReLU-28      [-1, 144, 16, 56, 56]               0
#            Conv3d-29       [-1, 64, 16, 56, 56]          27,648
#       BatchNorm3d-30       [-1, 64, 16, 56, 56]             128
#              ReLU-31       [-1, 64, 16, 56, 56]               0
#        BasicBlock-32       [-1, 64, 16, 56, 56]               0
#            Conv3d-33      [-1, 230, 16, 28, 28]         132,480
#       BatchNorm3d-34      [-1, 230, 16, 28, 28]             460
#              ReLU-35      [-1, 230, 16, 28, 28]               0
#            Conv3d-36       [-1, 128, 8, 28, 28]          88,320
#       BatchNorm3d-37       [-1, 128, 8, 28, 28]             256
#              ReLU-38       [-1, 128, 8, 28, 28]               0
#            Conv3d-39       [-1, 230, 8, 28, 28]         264,960
#       BatchNorm3d-40       [-1, 230, 8, 28, 28]             460
#              ReLU-41       [-1, 230, 8, 28, 28]               0
#            Conv3d-42       [-1, 128, 8, 28, 28]          88,320
#       BatchNorm3d-43       [-1, 128, 8, 28, 28]             256
#            Conv3d-44       [-1, 128, 8, 28, 28]           8,192
#       BatchNorm3d-45       [-1, 128, 8, 28, 28]             256
#              ReLU-46       [-1, 128, 8, 28, 28]               0
#        BasicBlock-47       [-1, 128, 8, 28, 28]               0
#            Conv3d-48       [-1, 288, 8, 28, 28]         331,776
#       BatchNorm3d-49       [-1, 288, 8, 28, 28]             576
#              ReLU-50       [-1, 288, 8, 28, 28]               0
#            Conv3d-51       [-1, 128, 8, 28, 28]         110,592
#       BatchNorm3d-52       [-1, 128, 8, 28, 28]             256
#              ReLU-53       [-1, 128, 8, 28, 28]               0
#            Conv3d-54       [-1, 288, 8, 28, 28]         331,776
#       BatchNorm3d-55       [-1, 288, 8, 28, 28]             576
#              ReLU-56       [-1, 288, 8, 28, 28]               0
#            Conv3d-57       [-1, 128, 8, 28, 28]         110,592
#       BatchNorm3d-58       [-1, 128, 8, 28, 28]             256
#              ReLU-59       [-1, 128, 8, 28, 28]               0
#        BasicBlock-60       [-1, 128, 8, 28, 28]               0
#            Conv3d-61       [-1, 460, 8, 14, 14]         529,920
#       BatchNorm3d-62       [-1, 460, 8, 14, 14]             920
#              ReLU-63       [-1, 460, 8, 14, 14]               0
#            Conv3d-64       [-1, 256, 4, 14, 14]         353,280
#       BatchNorm3d-65       [-1, 256, 4, 14, 14]             512
#              ReLU-66       [-1, 256, 4, 14, 14]               0
#            Conv3d-67       [-1, 460, 4, 14, 14]       1,059,840
#       BatchNorm3d-68       [-1, 460, 4, 14, 14]             920
#              ReLU-69       [-1, 460, 4, 14, 14]               0
#            Conv3d-70       [-1, 256, 4, 14, 14]         353,280
#       BatchNorm3d-71       [-1, 256, 4, 14, 14]             512
#            Conv3d-72       [-1, 256, 4, 14, 14]          32,768
#       BatchNorm3d-73       [-1, 256, 4, 14, 14]             512
#              ReLU-74       [-1, 256, 4, 14, 14]               0
#        BasicBlock-75       [-1, 256, 4, 14, 14]               0
#            Conv3d-76       [-1, 576, 4, 14, 14]       1,327,104
#       BatchNorm3d-77       [-1, 576, 4, 14, 14]           1,152
#              ReLU-78       [-1, 576, 4, 14, 14]               0
#            Conv3d-79       [-1, 256, 4, 14, 14]         442,368
#       BatchNorm3d-80       [-1, 256, 4, 14, 14]             512
#              ReLU-81       [-1, 256, 4, 14, 14]               0
#            Conv3d-82       [-1, 576, 4, 14, 14]       1,327,104
#       BatchNorm3d-83       [-1, 576, 4, 14, 14]           1,152
#              ReLU-84       [-1, 576, 4, 14, 14]               0
#            Conv3d-85       [-1, 256, 4, 14, 14]         442,368
#       BatchNorm3d-86       [-1, 256, 4, 14, 14]             512
#              ReLU-87       [-1, 256, 4, 14, 14]               0
#        BasicBlock-88       [-1, 256, 4, 14, 14]               0
#            Conv3d-89         [-1, 921, 4, 7, 7]       2,121,984
#       BatchNorm3d-90         [-1, 921, 4, 7, 7]           1,842
#              ReLU-91         [-1, 921, 4, 7, 7]               0
#            Conv3d-92         [-1, 512, 2, 7, 7]       1,414,656
#       BatchNorm3d-93         [-1, 512, 2, 7, 7]           1,024
#              ReLU-94         [-1, 512, 2, 7, 7]               0
#            Conv3d-95         [-1, 921, 2, 7, 7]       4,243,968
#       BatchNorm3d-96         [-1, 921, 2, 7, 7]           1,842
#              ReLU-97         [-1, 921, 2, 7, 7]               0
#            Conv3d-98         [-1, 512, 2, 7, 7]       1,414,656
#       BatchNorm3d-99         [-1, 512, 2, 7, 7]           1,024
#           Conv3d-100         [-1, 512, 2, 7, 7]         131,072
#      BatchNorm3d-101         [-1, 512, 2, 7, 7]           1,024
#             ReLU-102         [-1, 512, 2, 7, 7]               0
#       BasicBlock-103         [-1, 512, 2, 7, 7]               0
#           Conv3d-104        [-1, 1152, 2, 7, 7]       5,308,416
#      BatchNorm3d-105        [-1, 1152, 2, 7, 7]           2,304
#             ReLU-106        [-1, 1152, 2, 7, 7]               0
#           Conv3d-107         [-1, 512, 2, 7, 7]       1,769,472
#      BatchNorm3d-108         [-1, 512, 2, 7, 7]           1,024
#             ReLU-109         [-1, 512, 2, 7, 7]               0
#           Conv3d-110        [-1, 1152, 2, 7, 7]       5,308,416
#      BatchNorm3d-111        [-1, 1152, 2, 7, 7]           2,304
#             ReLU-112        [-1, 1152, 2, 7, 7]               0
#           Conv3d-113         [-1, 512, 2, 7, 7]       1,769,472
#      BatchNorm3d-114         [-1, 512, 2, 7, 7]           1,024
#             ReLU-115         [-1, 512, 2, 7, 7]               0
#       BasicBlock-116         [-1, 512, 2, 7, 7]               0
# ================================================================
# Total params: 31,300,125
# Trainable params: 31,300,125
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 2.30
# Forward/backward pass size (MB): 1496.85
# Params size (MB): 119.40
# Estimated Total Size (MB): 1618.54
# ----------------------------------------------------------------
